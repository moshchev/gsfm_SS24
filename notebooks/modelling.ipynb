# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyarrow.parquet as pq
from statsmodels.api import OLS
import statsmodels.api as sm

# %%
df = pd.read_parquet("../data/processed/ibes-forecasts_collapsed.parquet")

# %%
df = df.dropna(subset=["surprise","surprise_lag"])

# %%
inf_mask = np.isinf(df["surprise_lag"])
df = df[~inf_mask]

# %%
#corona variable
df['year_month'] = df['fiscal_period_ending'].dt.to_period('M')
df['Covid'] = ((df['year_month'] > '2020-01') & (df['year_month'] <= '2021-01')).astype(int)

# %% [markdown]
# # Hypotheses:
#
# #### 1. Hypothesis: Covid had an impact on analysts forecast accuarcy
# #### 2. Hypothesis: The analyst accuarcy increases, the closer the annouce date of the firm
# #### 3. Hypothesis: Analysts working at the biggest 10 % brokers by analyst count has a positive impact on PMAFE
# #### 4. Hypothesis: Analysts forecast accuarcy decreases with the number of industries followed

# %% [markdown]
# ---

# %%
#regression variables
variables = ["broker_coverage", "top_10", "broker_size", "analyst_following_jt", "analyst_portfolio_company_complexity_it", "analyst_portfolio_industry_complexity_it", "general_analyst_experience_log", "surprise_lag", "Covid", "mean_forecast_horizon_days"]

# %%
X = df.drop('pmafe', axis=1)
X = X[variables]
X = sm.add_constant(X) 
y = df['pmafe']

# %%
#correlation heatmap of some features
import seaborn as sns

plt.figure(figsize=(8, 6)) 
sns.heatmap(
    X.corr(numeric_only=True).round(2), annot=True, cmap="crest"
)

plt.title("Heatmap of the dataset")
plt.show()

# %% [markdown]
# ---
# #### 1. Hypothesis: Does increased analyst coverage positively correlates with accuracy

# %% [markdown]
# $$
# ACC_{i,j,t} = \alpha_0 + \alpha_1 AnalystFollowing_{i,j,t} + \alpha_2 Top10_{i,j,t} + \alpha_3 BrokerSize_{i,j,t} + \alpha_4 BrokerCoverage_{i,j,t} + \alpha_k X^k_{i,j,t} + \epsilon_{i,j,t}
# $$

# %%
print(OLS(y, X[["const", "analyst_following_jt", "top_10", "broker_size", "broker_coverage", "general_analyst_experience_log"]]).fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pmafe   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     69.54
# Date:                Fri, 08 Mar 2024   Prob (F-statistic):           5.78e-73
# Time:                        15:38:11   Log-Likelihood:            -5.0363e+05
# No. Observations:              490056   AIC:                         1.007e+06
# Df Residuals:                  490050   BIC:                         1.007e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              0.0143      0.004      3.215      0.001       0.006       0.023
# analyst_following_jt               0.0002    9.2e-05      2.510      0.012    5.06e-05       0.000
# top_10                            -0.0305      0.005     -6.097      0.000      -0.040      -0.021
# broker_size                     8.453e-05   2.25e-05      3.761      0.000    4.05e-05       0.000
# broker_coverage                    0.0168      0.003      5.960      0.000       0.011       0.022
# general_analyst_experience_log    -0.0146      0.001    -14.785      0.000      -0.017      -0.013
# ==============================================================================
# Omnibus:                   814596.640   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3461160535.190
# Skew:                          10.577   Prob(JB):                         0.00
# Kurtosis:                     414.168   Cond. No.                         488.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ---
# #### 2. Hypothesis: Does the breadth of industries or companies followed by analysts negatively influence the accuracy of their predictions?

# %% [markdown]
# $$
# ACC_{i,j,t} = \alpha_0 + \alpha_1 PortCompanyComplexity_{i,j,t} + \alpha_2 PortIndustryComplexity_{i,j,t} + \alpha_k X^k_{i,j,t} + \epsilon_{i,j,t}
# $$

# %%
print(OLS(y, X[["const", "analyst_portfolio_company_complexity_it", "analyst_portfolio_industry_complexity_it", "broker_size", "general_analyst_experience_log", "surprise_lag", "mean_forecast_horizon_days"]]).fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pmafe   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     2432.
# Date:                Fri, 08 Mar 2024   Prob (F-statistic):               0.00
# Time:                        15:38:11   Log-Likelihood:            -4.9780e+05
# No. Observations:              490056   AIC:                         9.956e+05
# Df Residuals:                  490050   BIC:                         9.957e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                       -0.0069   8.24e-05    -83.623      0.000      -0.007      -0.007
# analyst_portfolio_company_complexity_it      0.0009   9.96e-05      9.458      0.000       0.001       0.001
# analyst_portfolio_industry_complexity_it    -0.0011      0.000     -2.963      0.003      -0.002      -0.000
# broker_size                                 -0.0005   1.58e-05    -31.188      0.000      -0.001      -0.000
# general_analyst_experience_log              -0.0784      0.001    -83.163      0.000      -0.080      -0.077
# surprise_lag                             -9.812e-19   1.72e-18     -0.571      0.568   -4.35e-18    2.39e-18
# mean_forecast_horizon_days                   0.0012   1.16e-05    103.854      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                   825037.645   Durbin-Watson:                   1.724
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3808379223.166
# Skew:                          10.853   Prob(JB):                         0.00
# Kurtosis:                     434.324   Cond. No.                     2.33e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.33e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ---
# #### 3. Hypothesis: Does the general experience of analysts positively affect their accuracy and does the degree of the surprise in the previous period matter​

# %% [markdown]
# $$
# ACC_{i,j,t} = \alpha_0 + \alpha_1 ExpLog_{i,j,t} + \alpha_2 SurpriseLag_{i,j,t} + \alpha_k X^k_{i,j,t} + \epsilon_{i,j,t}
# $$

# %%
print(OLS(y, X[["const", "general_analyst_experience_log", "surprise_lag", "broker_size", "analyst_portfolio_company_complexity_it", "analyst_portfolio_industry_complexity_it"]]).fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pmafe   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     333.6
# Date:                Fri, 08 Mar 2024   Prob (F-statistic):          2.66e-287
# Time:                        15:38:11   Log-Likelihood:            -5.0314e+05
# No. Observations:              490056   AIC:                         1.006e+06
# Df Residuals:                  490051   BIC:                         1.006e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                       -0.0052      0.000    -27.899      0.000      -0.006      -0.005
# general_analyst_experience_log              -0.0214      0.001    -28.387      0.000      -0.023      -0.020
# surprise_lag                             -3.112e-18   1.74e-18     -1.790      0.073   -6.52e-18    2.95e-19
# broker_size                               4.577e-07   1.54e-05      0.030      0.976   -2.97e-05    3.06e-05
# analyst_portfolio_company_complexity_it      0.0021      0.000     21.060      0.000       0.002       0.002
# analyst_portfolio_industry_complexity_it     0.0050      0.000     13.688      0.000       0.004       0.006
# ==============================================================================
# Omnibus:                   812496.991   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3435337948.659
# Skew:                          10.518   Prob(JB):                         0.00
# Kurtosis:                     412.634   Cond. No.                     1.60e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.6e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ---
# #### 4. Hypothesis: Does the occurrence of Covid affect the accuracy of analysts' forecasts?​

# %% [markdown]
# $$
# ACC_{i,j,t} = \alpha_0 + \alpha_1 Covid_{i,j,t} + \epsilon_{i,j,t}
# $$

# %%
print(OLS(y, X[["const", "Covid"]]).fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pmafe   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.354
# Date:                Fri, 08 Mar 2024   Prob (F-statistic):              0.245
# Time:                        15:38:11   Log-Likelihood:            -5.0381e+05
# No. Observations:              490056   AIC:                         1.008e+06
# Df Residuals:                  490054   BIC:                         1.008e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0105      0.001     10.476      0.000       0.009       0.012
# Covid         -0.0043      0.004     -1.164      0.245      -0.012       0.003
# ==============================================================================
# Omnibus:                   815465.718   Durbin-Watson:                   1.751
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3469862473.714
# Skew:                          10.602   Prob(JB):                         0.00
# Kurtosis:                     414.684   Cond. No.                         3.89
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ---
# #### Final Model

# %% [markdown]
# $$Acc_{ijt} = \alpha[i] + \beta_{BCOV} * BCOV_{ijt} + \beta_{TOP10} * TOP10_{ijt} + \beta_{BSIZE} * BSIZE_{ijt} + \beta_{FOLLW} * FOLLW_{ijt} + \beta_{PCOMC} * PCOMC_{ijt}$$
#
# $$+ \beta_{PCOMI} * PCOMI_{ijt} + \beta_{EXPLOG} * EXPLOG_{ijt} + \beta_{SURPLAG} * SURPLAG_{ijt} + \beta_{COVID} * COVID_{ijt} + \beta_{HORZ} * HORZ_{ijt}$$

# %%
print(OLS(y, X).fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pmafe   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     2793.
# Date:                Fri, 08 Mar 2024   Prob (F-statistic):               0.00
# Time:                        15:38:12   Log-Likelihood:            -4.9692e+05
# No. Observations:              490056   AIC:                         9.939e+05
# Df Residuals:                  490050   BIC:                         9.939e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                       -0.0062   7.76e-05    -79.811      0.000      -0.006      -0.006
# broker_coverage                             -0.0032   3.92e-05    -80.444      0.000      -0.003      -0.003
# top_10                                      -0.0001   1.91e-06    -74.018      0.000      -0.000      -0.000
# broker_size                                 -0.0004   1.59e-05    -26.936      0.000      -0.000      -0.000
# analyst_following_jt                        -0.0035   8.75e-05    -39.646      0.000      -0.004      -0.003
# analyst_portfolio_company_complexity_it      0.0011   9.96e-05     11.270      0.000       0.001       0.001
# analyst_portfolio_industry_complexity_it    -0.0006      0.000     -1.748      0.080      -0.001    7.76e-05
# general_analyst_experience_log              -0.0749      0.001    -79.139      0.000      -0.077      -0.073
# surprise_lag                             -7.295e-19   1.71e-18     -0.425      0.670   -4.09e-18    2.63e-18
# Covid                                       -0.0011   1.38e-05    -78.962      0.000      -0.001      -0.001
# mean_forecast_horizon_days                   0.0014   1.27e-05    112.086      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                   829055.622   Durbin-Watson:                   1.719
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3913641140.816
# Skew:                          10.965   Prob(JB):                         0.00
# Kurtosis:                     440.248   Cond. No.                     3.31e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.31e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ---
# #### Fixed Effects

# %%
# Perform mean aggregation
subset_df = X.copy(deep=True)
subset_df["analyst"] = df["analyst"]
subset_df["pmafe"] = y
mean_df = subset_df.groupby("analyst").mean()
demeaned_df = subset_df.set_index("analyst") - mean_df
demeaned_df_y = demeaned_df["pmafe"]
demeaned_df_X = demeaned_df.drop("pmafe", axis=1)
demeaned_df_X.loc[demeaned_df_X["const"] == 0.0, "const"] = 1.0

# %%
print(OLS(demeaned_df_y, demeaned_df_X).fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  pmafe   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     5895.
# Date:                Fri, 08 Mar 2024   Prob (F-statistic):               0.00
# Time:                        15:38:12   Log-Likelihood:            -4.5856e+05
# No. Observations:              490056   AIC:                         9.171e+05
# Df Residuals:                  490051   BIC:                         9.172e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# const                                    -2.873e-18      0.001  -3.26e-15      1.000      -0.002       0.002
# broker_coverage                          -6.835e-06   9.68e-07     -7.060      0.000   -8.73e-06   -4.94e-06
# top_10                                   -9.881e-07    9.9e-07     -0.998      0.318   -2.93e-06    9.53e-07
# broker_size                               9.146e-05   4.22e-05      2.166      0.030     8.7e-06       0.000
# analyst_following_jt                        -0.0022      0.000    -20.048      0.000      -0.002      -0.002
# analyst_portfolio_company_complexity_it      0.0004      0.000      1.974      0.048    2.96e-06       0.001
# analyst_portfolio_industry_complexity_it     0.0011      0.001      1.136      0.256      -0.001       0.003
# general_analyst_experience_log            5.105e-05   2.96e-05      1.725      0.085   -6.95e-06       0.000
# surprise_lag                             -1.124e-18    1.6e-18     -0.704      0.481   -4.25e-18       2e-18
# Covid                                     6.266e-06    3.1e-06      2.020      0.043    1.85e-07    1.23e-05
# mean_forecast_horizon_days                   0.0025   1.66e-05    153.175      0.000       0.003       0.003
# ==============================================================================
# Omnibus:                   793737.951   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4080565122.992
# Skew:                           9.902   Prob(JB):                         0.00
# Kurtosis:                     449.598   Cond. No.                     4.76e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.76e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ---
# Lasso Regression

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.3)
lasso.fit(X,y)

data = {
    "Variables": X.columns,
    "Lasso Coefficients": lasso.coef_,
}

df_lasso = pd.DataFrame(data)
df_lasso
# Out:
#                                    Variables  Lasso Coefficients
# 0                                      const        0.000000e+00
# 1                            broker_coverage        0.000000e+00
# 2                                     top_10       -0.000000e+00
# 3                                broker_size        0.000000e+00
# 4                       analyst_following_jt       -0.000000e+00
# 5    analyst_portfolio_company_complexity_it        0.000000e+00
# 6   analyst_portfolio_industry_complexity_it        0.000000e+00
# 7             general_analyst_experience_log       -0.000000e+00
# 8                               surprise_lag       -9.080356e-19
# 9                                      Covid       -0.000000e+00
# 10                mean_forecast_horizon_days        2.387010e-03
